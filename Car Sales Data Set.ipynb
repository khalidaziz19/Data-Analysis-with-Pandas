# %%
# import pandas 
import pandas as pd 

file = r'C:\Users\saarah.rasheed\Downloads\archive\Car_sales.csv'

data = pd.read_csv(file)

# %%
data.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
# ...

# %%
data.shape
# Out:
# (157, 16)

# %%
data.isna().any()
# Out:
# Manufacturer           False
# Model                  False
# Sales_in_thousands     False
# __year_resale_value     True
# Vehicle_type           False
# Price_in_thousands      True
# Engine_size             True
# Horsepower              True
# Wheelbase               True
# Width                   True
# Length                  True
# Curb_weight             True
# Fuel_capacity           True
# Fuel_efficiency         True
# Latest_Launch          False
# Power_perf_factor       True
# dtype: bool

# %%
column_name = '__year_resale_value'
# column_name = 'Price_in_thousands'
subset = data[column_name].isna()
# data[subset.isna()]
data[subset]
# to see number of obs where row is nan
# data[subset].shape
# Out:
#     Manufacturer      Model  Sales_in_thousands  __year_resale_value  \
# 7            BMW       323i              19.747                  NaN
# 18      Cadillac   Escalade              14.785                  NaN
# 27     Chevrolet     Impala             107.995                  NaN
# 34      Chrysler       300M              30.696                  NaN
# 44         Dodge    Durango             101.323                  NaN
# 50          Ford      Focus             175.670                  NaN
# 66        Jaguar     S-Type              15.467                  NaN
# 72         Lexus      GS400               3.334                  NaN
# 74         Lexus      LX470               9.126                  NaN
# 75         Lexus      RX300              51.238                  NaN
# 78       Lincoln  Navigator              22.925                  NaN
# 96    Mercedes-B        SLK               7.998                  NaN
# 97    Mercedes-B     SLK230               1.526                  NaN
# ...

# %%
dummy = data[subset].fillna(-9999999)
dummy.replace(-9999999, 0)
# Out:
#     Manufacturer      Model  Sales_in_thousands  __year_resale_value  \
# 7            BMW       323i              19.747                  0.0
# 18      Cadillac   Escalade              14.785                  0.0
# 27     Chevrolet     Impala             107.995                  0.0
# 34      Chrysler       300M              30.696                  0.0
# 44         Dodge    Durango             101.323                  0.0
# 50          Ford      Focus             175.670                  0.0
# 66        Jaguar     S-Type              15.467                  0.0
# 72         Lexus      GS400               3.334                  0.0
# 74         Lexus      LX470               9.126                  0.0
# 75         Lexus      RX300              51.238                  0.0
# 78       Lincoln  Navigator              22.925                  0.0
# 96    Mercedes-B        SLK               7.998                  0.0
# 97    Mercedes-B     SLK230               1.526                  0.0
# ...

# %%
# data.dropna()
data.shape
# Out:
# (157, 16)

# %%
fixed_data = data.dropna()

# %%
fixed_data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# 5           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 145   Volkswagen     Golf               9.761               11.425
# 146   Volkswagen    Jetta              83.721               13.240
# 147   Volkswagen   Passat              51.102               16.725
# 148   Volkswagen   Cabrio               9.569               16.575
# 149   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
data['Latest_Launch']
# Out:
# 0        2/2/2012
# 1        6/3/2011
# 2        1/4/2012
# 3       3/10/2011
# 4       10/8/2011
#           ...
# 152     9/21/2011
# 153    11/24/2012
# 154     6/25/2011
# 155     4/26/2011
# 156    11/14/2011
# Name: Latest_Launch, Length: 157, dtype: object

# %%
pd.set_option('display.max_rows', 1000)

# %%
data['Latest_Launch']
# Out:
# 0        2/2/2012
# 1        6/3/2011
# 2        1/4/2012
# 3       3/10/2011
# 4       10/8/2011
# 5        8/9/2011
# 6       2/27/2012
# 7       6/28/2011
# 8       1/29/2012
# 9        4/4/2011
# 10      11/2/2011
# 11       9/3/2011
# 12      3/23/2012
# 13      7/23/2011
# 14      2/23/2012
# 15      4/29/2011
# 16     11/27/2011
# 17      9/28/2011
# 18      4/17/2012
# 19      8/17/2011
# 20      3/19/2012
# 21      5/24/2011
# 22     12/22/2011
# 23     10/23/2011
# 24      5/12/2012
# 25      9/11/2011
# 26      4/13/2012
# 27      6/18/2011
# 28      1/16/2012
# 29     11/17/2011
# 30       6/6/2012
# 31      10/6/2011
# 32       5/8/2012
# 33      7/13/2011
# 34      2/10/2012
# 35     12/12/2011
# 36       7/1/2012
# 37     10/31/2011
# 38       6/2/2012
# 39       8/7/2011
# 40       3/6/2012
# 41       1/6/2012
# 42      7/26/2012
# 43     11/25/2011
# 44      6/27/2012
# 45       9/1/2011
# 46      3/31/2012
# 47      1/31/2012
# 48      8/20/2012
# 49     12/20/2011
# ...

# %%
# convert string dates into datetime objects 
fixed_dates = pd.to_datetime(data['Latest_Launch'])

# %%
# check data types 
fixed_dates.iloc[0]
type(fixed_dates.iloc[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
type(data['Latest_Launch'].iloc[0])
# Out:
# str

# %%
# help(fixed_dates.iloc[0])

# %%
# access attributes into our datasets. We can view .year, .month, .day, .week, .monthname 
fixed_dates.iloc[0].year
# Out:
# 2012

# %%
fixed_data['Latest_Launch'] = fixed_dates
# Out:
# <ipython-input-57-6779f4090f36>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fixed_data['Latest_Launch'] = fixed_dates

# %%
fixed_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 0 to 149
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         117 non-null    object
#  1   Model                117 non-null    object
#  2   Sales_in_thousands   117 non-null    float64
#  3   __year_resale_value  117 non-null    float64
#  4   Vehicle_type         117 non-null    object
#  5   Price_in_thousands   117 non-null    float64
#  6   Engine_size          117 non-null    float64
#  7   Horsepower           117 non-null    float64
#  8   Wheelbase            117 non-null    float64
#  9   Width                117 non-null    float64
#  10  Length               117 non-null    float64
#  11  Curb_weight          117 non-null    float64
#  12  Fuel_capacity        117 non-null    float64
#  13  Fuel_efficiency      117 non-null    float64
#  14  Latest_Launch        117 non-null    datetime64[ns]
# ...

# %%
# identify duplicate model
fixed_data[fixed_data['Model'].duplicated()]
# Out:
#     Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 114     Plymouth  Neon              32.734                 7.75    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 114               12.64          2.0       132.0      105.0   74.4   174.4
#
#      Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 114        2.559           12.5             29.0    2011-04-26
#
#      Power_perf_factor
# 114          52.084899

# %%
# retreive duplicate model
fixed_data[fixed_data['Model'] == 'Neon']
# Out:
#     Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 35         Dodge  Neon              76.034                 7.75    Passenger
# 114     Plymouth  Neon              32.734                 7.75    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 35                12.64          2.0       132.0      105.0   74.4   174.4
# 114               12.64          2.0       132.0      105.0   74.4   174.4
#
#      Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 35         2.567           12.5             29.0    2011-12-12
# 114        2.559           12.5             29.0    2011-04-26
#
#      Power_perf_factor
# 35           52.084899
# 114          52.084899

# %%
# we did some googling to figure out whether to keep these values or not.
# we realized that both Dodge and Plymouth are actually the same rebranded company 
# so we decided to remove the older one (Plymouth)

# remove our duplicate model
fixed_data1 = fixed_data.drop(index=[114])

# %%
fixed_data1
# Out:
#     Manufacturer           Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura         Integra              16.919               16.360
# 1          Acura              TL              39.384               19.875
# 3          Acura              RL               8.588               29.725
# 4           Audi              A4              20.397               22.255
# 5           Audi              A6              18.780               23.555
# 6           Audi              A8               1.380               39.000
# 8            BMW            328i               9.231               28.675
# 9            BMW            528i              17.527               36.125
# 10         Buick         Century              91.561               12.475
# 11         Buick           Regal              39.350               13.740
# 12         Buick     Park Avenue              27.851               20.190
# 13         Buick         LeSabre              83.257               13.360
# ...

# %%
fixed_data.shape
# Out:
# (117, 16)

# %%
fixed_data1.shape
# Out:
# (116, 16)

# %% [markdown]
# Groupby function requires:
# - The column (categorical variable) to group on
# - The column to display (this can be either categorical or numerical)
# - The aggregation function (count, min, max, average etc)

# %%
# in practice:
temp = fixed_data.groupby('Manufacturer')['Vehicle_type']

# %%
# check the index 
temp.count().idxmax()
# check the value
# temp.count().max()
# Out:
# 'Ford'
